# %%
import ripropagate

# %% [markdown]
# ## 03/26/24
# Testing fastscape base model, using the Zwaan prm as a guide.

# %%
ripropagate.generate(etime=0.1,evel=-1,lthick=120,output='./032624_rif',file='ri_base_fs.prm',soft=0.375,depth=600,p1=400,p2=200, shell='run_base.sh',ver='a',nodes=1)
ripropagate.comp_ascii(depth=600,output='./032624_rif',seed=20,non_initial=True,thicknesses=[20,20,80])
# Out:
# (array([[      0.,       0.,       0., ...,       0.,       0.,       0.],
#         [   2000.,    2000.,    2000., ...,    2000.,    2000.,    2000.],
#         [   4000.,    4000.,    4000., ...,    4000.,    4000.,    4000.],
#         ...,
#         [ 996000.,  996000.,  996000., ...,  996000.,  996000.,  996000.],
#         [ 998000.,  998000.,  998000., ...,  998000.,  998000.,  998000.],
#         [1000000., 1000000., 1000000., ..., 1000000., 1000000., 1000000.]]),
#  array([[     0.,   2000.,   4000., ..., 596000., 598000., 600000.],
#         [     0.,   2000.,   4000., ..., 596000., 598000., 600000.],
#         [     0.,   2000.,   4000., ..., 596000., 598000., 600000.],
#         ...,
#         [     0.,   2000.,   4000., ..., 596000., 598000., 600000.],
#         [     0.,   2000.,   4000., ..., 596000., 598000., 600000.],
#         [     0.,   2000.,   4000., ..., 596000., 598000., 600000.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.],
# ...

# %% [markdown]
# ## 4/4/24
# Modified the PRM to (partially) match the Brazil model from John

# %%
ripropagate.generate(etime=0.1,evel=-1,lthick=120,output='./040424_rif',file='ri_base_fs.prm',soft=0.375,depth=600,p1=400,p2=200, shell='run_base.sh',ver='a',nodes=1)
ripropagate.comp_ascii(depth=600,output='./040424_rif',seed=20,non_initial=True,thicknesses=[20,20,80])
# Out:
# (array([[      0.,       0.,       0., ...,       0.,       0.,       0.],
#         [   2000.,    2000.,    2000., ...,    2000.,    2000.,    2000.],
#         [   4000.,    4000.,    4000., ...,    4000.,    4000.,    4000.],
#         ...,
#         [ 996000.,  996000.,  996000., ...,  996000.,  996000.,  996000.],
#         [ 998000.,  998000.,  998000., ...,  998000.,  998000.,  998000.],
#         [1000000., 1000000., 1000000., ..., 1000000., 1000000., 1000000.]]),
#  array([[     0.,   2000.,   4000., ..., 596000., 598000., 600000.],
#         [     0.,   2000.,   4000., ..., 596000., 598000., 600000.],
#         [     0.,   2000.,   4000., ..., 596000., 598000., 600000.],
#         ...,
#         [     0.,   2000.,   4000., ..., 596000., 598000., 600000.],
#         [     0.,   2000.,   4000., ..., 596000., 598000., 600000.],
#         [     0.,   2000.,   4000., ..., 596000., 598000., 600000.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.],
# ...

# %% [markdown]
# ## 4/19/24
# Discovered I was trying to start with inversion instead of rifting, so starting over a new test.

# %%
ripropagate.generate(etime=16,evel=0.5,lthick=120,output='./041924_rif',file='ri_base_fs.prm',soft=0.375,depth=600,p1=400,p2=200, shell='run_tufts.sh',ver='a',nodes=4)
ripropagate.comp_ascii(depth=600,output='./041924_rif',seed=20,non_initial=True,thicknesses=[20,20,80])
# Out:
# (array([[      0.,       0.,       0., ...,       0.,       0.,       0.],
#         [   2000.,    2000.,    2000., ...,    2000.,    2000.,    2000.],
#         [   4000.,    4000.,    4000., ...,    4000.,    4000.,    4000.],
#         ...,
#         [ 996000.,  996000.,  996000., ...,  996000.,  996000.,  996000.],
#         [ 998000.,  998000.,  998000., ...,  998000.,  998000.,  998000.],
#         [1000000., 1000000., 1000000., ..., 1000000., 1000000., 1000000.]]),
#  array([[     0.,   2000.,   4000., ..., 596000., 598000., 600000.],
#         [     0.,   2000.,   4000., ..., 596000., 598000., 600000.],
#         [     0.,   2000.,   4000., ..., 596000., 598000., 600000.],
#         ...,
#         [     0.,   2000.,   4000., ..., 596000., 598000., 600000.],
#         [     0.,   2000.,   4000., ..., 596000., 598000., 600000.],
#         [     0.,   2000.,   4000., ..., 596000., 598000., 600000.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.],
# ...

# %% [markdown]
# ## 4/23/24
#
# Attempting to invert the low n version of this model

# %%
ripropagate.generate(etime=36,evel=-1,lthick=120,output='./042324_rif',file='ri_base_fs_lown.prm',soft=0.375,depth=600,p1=400,p2=200, shell='run_tufts.sh',ver='a',nodes=2)

# %% [markdown]
# ## 4/26/24
# Attempting to invert the high n version

# %%
ripropagate.generate(etime=36,evel=-1,lthick=120,output='./042624_rif',file='ri_base_fs.prm',soft=0.375,depth=600,p1=400,p2=200, shell='run_tufts.sh',ver='a',nodes=2)

# %% [markdown]
# ## 5/28/24
# Creating a base model to do tests on boundary conditions

# %%
ripropagate.generate(etime=16,evel=0.5,lthick=120,output='./052824_rif',file='ri_base_fs_lown.prm',soft=0.375,depth=600,p1=400,p2=200, shell='run_tufts.sh',ver='a',nodes=2)
ripropagate.comp_ascii(depth=600,output='./052824_rif',seed=20,non_initial=True,thicknesses=[20,20,80])
# Out:
# (array([[      0.,       0.,       0., ...,       0.,       0.,       0.],
#         [   2000.,    2000.,    2000., ...,    2000.,    2000.,    2000.],
#         [   4000.,    4000.,    4000., ...,    4000.,    4000.,    4000.],
#         ...,
#         [ 996000.,  996000.,  996000., ...,  996000.,  996000.,  996000.],
#         [ 998000.,  998000.,  998000., ...,  998000.,  998000.,  998000.],
#         [1000000., 1000000., 1000000., ..., 1000000., 1000000., 1000000.]]),
#  array([[     0.,   2000.,   4000., ..., 596000., 598000., 600000.],
#         [     0.,   2000.,   4000., ..., 596000., 598000., 600000.],
#         [     0.,   2000.,   4000., ..., 596000., 598000., 600000.],
#         ...,
#         [     0.,   2000.,   4000., ..., 596000., 598000., 600000.],
#         [     0.,   2000.,   4000., ..., 596000., 598000., 600000.],
#         [     0.,   2000.,   4000., ..., 596000., 598000., 600000.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.],
# ...

# %% [markdown]
# ## 6/5/24
# Have both an original and efficient solver model running from manual prms. Creating inversion prms for those.

# %%
ripropagate.generate(etime=36,evel=-1,lthick=120,output='./060524_rif_eff',file='ri_base_fs_lown_eff.prm',soft=0.375,depth=600,p1=400,p2=200, shell='run_tufts.sh',ver='a',nodes=2)
ripropagate.generate(etime=36,evel=-1,lthick=120,output='./060524_rif',file='ri_base_fs_lown.prm',soft=0.375,depth=600,p1=400,p2=200, shell='run_tufts.sh',ver='b',nodes=2)

# %% [markdown]
# Also want to try a version of DT

# %%
ripropagate.generate(etime=7.3,evel=-2,lthick=80,output='./060524_rif_eff_dt',file='ri_base_fs_lown_eff.prm',soft=0.375,depth=600,p1=400,p2=200, shell='run_tufts.sh',ver='c',nodes=2)
